# %% [markdown]
# # Read in data and check duplicated rows

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/Users/yuhancheng/Downloads/df.csv')
print('Number of Duplicated rows:',sum(df.duplicated())) #check if there is duplicated line

# %% [markdown]
# # Drop the columns that we don't need

# %%
#drop features that we don't need
df = df.drop(columns = ['MLS No', 'Status', 'Address', 'City'])

# %% [markdown]
# # Change sell price and list price to numeric

# %%
#change the type of LP and SP to numeric
def remove(text):
    return text.replace('$','')
def removedot(text):
    return text.replace(',','')
df['LP'] = pd.to_numeric(df['LP'].apply(remove).apply(removedot))
df['SP'] = pd.to_numeric(df['SP'].apply(remove).apply(removedot))

# %% [markdown]
# # Change closing date to datetime and train test split by closing date

# %%
#output train test dataset
df['Closing Date'] = pd.to_datetime(df['Closing Date'])
df = df.sort_values(by = 'Closing Date', ignore_index=True)
#df = df.drop(columns= 'Unnamed: 0')
train = df.iloc[0:7000]
test = df.iloc[7000:]
train.to_csv('train.csv')
test.to_csv('test.csv')

# %%
train
# Out:
#      Unit  DOM      LP      SP  BT  SqFt  BR  Bth  Gar  GarSp   YrBlt HOA Fee  \
# 0     NaN   17  769000  759000  CO  1257   2    2    Y    2.0  1999.0     341
# 1     NaN   51  649000  636000  CO   922   2    2  NaN    0.0  1988.0     460
# 2     NaN    7  750000  785000  TH  1655   3    2    Y    2.0  1982.0     445
# 3     NaN   15  674888  723000  DE  1408   3    3  NaN    0.0  1953.0     NaN
# 4     NaN    7  549000  600000  TH  1234   2    1    Y    2.0  1981.0     284
# ...   ...  ...     ...     ...  ..   ...  ..  ...  ...    ...     ...     ...
# 6995  416    4  849000  822000  CO  1622   2    2    Y    2.0  1998.0     726
# 6996  NaN    1  715000  766000  CO  1168   2    2    Y    2.0  1996.0     260
# 6997  NaN    9  887999  894000  DE  1568   4    2    Y    2.0  1998.0      50
# 6998    8    6  889500  905000  CO  1464   2    2  NaN    0.0  2013.0     210
# 6999    8   12  889500  905000  CO  1464   2    2    Y    2.0  2013.0     210
#
#      Freq Closing Date   Age              Area    Zip
# 0     NaN   2019-01-02  19.0      Santa Teresa  95138
# 1     NaN   2019-01-02  30.0          Campbell  95128
# 2     NaN   2019-01-02  36.0      Santa Teresa  95139
# 3     NaN   2019-01-02  65.0         Alum Rock  95127
# 4     NaN   2019-01-02  37.0         Evergreen  95121
# ...   ...          ...   ...               ...    ...
# 6995    M   2020-12-22  22.0  Central San Jose  95112
# 6996    M   2020-12-22  24.0    South San Jose  95136
# 6997    M   2020-12-22  22.0    South San Jose  95111
# 6998    M   2020-12-22   8.0         Berryessa  95132
# 6999    M   2020-12-22   7.0         Berryessa  95132
#
# [7000 rows x 17 columns]

# %%
test
# Out:
#      Unit  DOM      LP      SP  BT  SqFt  BR  Bth  Gar  GarSp   YrBlt HOA Fee  \
# 7000  NaN    6  799999  935000  DE  1398   4    2    Y    2.0  1971.0     NaN
# 7001    2   14  514000  505000  CO   903   2    1    Y    1.0  1970.0     379
# 7002  NaN   25  549000  550000  CO  1094   2    2  NaN    0.0  1991.0     463
# 7003  NaN   10  949000  985000  DE  1065   3    2    Y    2.0  1971.0     NaN
# 7004  NaN   14  900000  915000  DE  1439   3    2  NaN    0.0  1920.0     NaN
# ...   ...  ...     ...     ...  ..   ...  ..  ...  ...    ...     ...     ...
# 9995  NaN   56  460000  450000  CO  1240   2    2  NaN    0.0  1968.0     822
# 9996  NaN    7  549000  615000  CO  1008   2    1    Y    2.0  1987.0     320
# 9997  NaN    0  650000  685000  CO  1452   3    2    Y    2.0  1986.0     380
# 9998  NaN    5  667053  675000  CO  1233   2    2    Y    1.0  1985.0     535
# 9999    E   24  699000  715000  TH  1093   2    2    Y    1.0  1992.0     349
#
#      Freq Closing Date    Age              Area    Zip
# 7000  NaN   2020-12-22   49.0         Evergreen  95148
# 7001    M   2020-12-22   50.0          Cambrian  95118
# 7002    M   2020-12-23   29.0    South San Jose  95122
# 7003  NaN   2020-12-23   49.0    Blossom Valley  95123
# 7004  NaN   2020-12-23  100.0  Central San Jose  95112
# ...   ...          ...    ...               ...    ...
# 9995    M   2021-10-08   53.0         Evergreen  95135
# 9996    M   2021-10-08   34.0    South San Jose  95111
# 9997  NaN   2021-10-08   35.0    Blossom Valley  95136
# 9998    M   2021-10-08   36.0    Blossom Valley  95123
# 9999    M   2021-10-08   29.0      Santa Teresa  95138
#
# [3000 rows x 17 columns]

# %% [markdown]
# # Plot sell price with closing date

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

df['logSP'] = np.log(df['SP'])
fig = make_subplots(rows=1, cols=2,subplot_titles=("Selling price","Log Selling Price"))

fig.add_trace(
    go.Scatter(x=df['Closing Date'], y=df['SP'],mode = 'markers', name = 'Selling Price'),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(x=df['Closing Date'], y=df['logSP'],mode = 'markers', name = 'Log Selling Price'),
    row=1, col=2
)

fig.update_layout(height=400, width=1000)
fig.show()
# Out:
# <div>                            <div id="bfb22bcb-b8df-4851-a019-044a8d2fb446" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfb22bcb-b8df-4851-a019-044a8d2fb446")) {                    Plotly.newPlot(                        "bfb22bcb-b8df-4851-a019-044a8d2fb446",                        [{"mode":"markers","name":"Selling Price","type":"scatter","x":["2019-01-02T00:00:00","2019-01-02T00:00:00","2019-01-02T00:00:00","2019-01-02T00:00:00","2019-01-02T00:00:00","2019-01-02T00:00:00","2019-01-02T00:00:00","2019-01-02T00:00:00","2019-01-02T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-03T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-04T00:00:00","2019-01-04T00:00:00","2019-01-04T00:00:00","2019-01-04T00:00:00","2019-01-04T00:00:00","2019-01-04T00:00:00","2019-01-04T00:00:00","2019-01-04T00:00:00","2019-01-04T00:00:00","2019-01-04T00:00:00","2019-01-06T00:00:00","2019-01-07T00:00:00","2019-01-07T00:00:00","2019-01-07T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-08T00:00:00","2019-01-08T00:00:00","2019-01-08T00:00:00","2019-01-08T00:00:00","2019-01-08T00:00:00","2019-01-08T00:00:00","2019-01-08T00:00:00","2019-01-08T00:00:00","2019-01-08T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-09T00:00:00","2019-01-09T00:00:00","2019-01-09T00:00:00","2019-01-09T00:00:00","2019-01-09T00:00:00","2019-01-09T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-10T00:00:00","2019-01-10T00:00:00","2019-01-10T00:00:00","2019-01-10T00:00:00","2019-01-10T00:00:00","2019-01-10T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-11T00:00:00","2019-01-12T00:00:00","2019-01-12T00:00:00","2019-01-14T00:00:00","2019-01-14T00:00:00","2019-01-14T00:00:00","2019-01-14T00:00:00","2019-01-14T00:00:00","2019-01-14T00:00:00","2019-01-14T00:00:00","2019-01-14T00:00:00","2019-01-14T00:00:00","2019-01-14T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-17T00:00:00","2019-01-17T00:00:00","2019-01-17T00:00:00","2019-01-17T00:00:00","2019-01-17T00:00:00","2019-01-17T00:00:00","2019-01-17T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-18T00:00:00","2019-01-22T00:00:00","2019-01-22T00:00:00","2019-01-22T00:00:00","2019-01-22T00:00:00","2019-01-22T00:00:00","2019-01-22T00:00:00","2019-01-22T00:00:00","2019-01-22T00:00:00","2019-01-23T00:0 ...

# %% [markdown]
# # Extract month and week of month as feature

# %%
import warnings
warnings.filterwarnings('ignore')

train['month_of_date'] = train['Closing Date'].dt.month
test['month_of_date'] = test['Closing Date'].dt.month

# %%
test
# Out:
#      Unit  DOM      LP      SP  BT  SqFt  BR  Bth  Gar  GarSp   YrBlt HOA Fee  \
# 7000  NaN    6  799999  935000  DE  1398   4    2    Y    2.0  1971.0     NaN
# 7001    2   14  514000  505000  CO   903   2    1    Y    1.0  1970.0     379
# 7002  NaN   25  549000  550000  CO  1094   2    2  NaN    0.0  1991.0     463
# 7003  NaN   10  949000  985000  DE  1065   3    2    Y    2.0  1971.0     NaN
# 7004  NaN   14  900000  915000  DE  1439   3    2  NaN    0.0  1920.0     NaN
# ...   ...  ...     ...     ...  ..   ...  ..  ...  ...    ...     ...     ...
# 9995  NaN   56  460000  450000  CO  1240   2    2  NaN    0.0  1968.0     822
# 9996  NaN    7  549000  615000  CO  1008   2    1    Y    2.0  1987.0     320
# 9997  NaN    0  650000  685000  CO  1452   3    2    Y    2.0  1986.0     380
# 9998  NaN    5  667053  675000  CO  1233   2    2    Y    1.0  1985.0     535
# 9999    E   24  699000  715000  TH  1093   2    2    Y    1.0  1992.0     349
#
#      Freq Closing Date    Age              Area    Zip  month_of_date
# 7000  NaN   2020-12-22   49.0         Evergreen  95148             12
# 7001    M   2020-12-22   50.0          Cambrian  95118             12
# 7002    M   2020-12-23   29.0    South San Jose  95122             12
# 7003  NaN   2020-12-23   49.0    Blossom Valley  95123             12
# 7004  NaN   2020-12-23  100.0  Central San Jose  95112             12
# ...   ...          ...    ...               ...    ...            ...
# 9995    M   2021-10-08   53.0         Evergreen  95135             10
# 9996    M   2021-10-08   34.0    South San Jose  95111             10
# 9997  NaN   2021-10-08   35.0    Blossom Valley  95136             10
# 9998    M   2021-10-08   36.0    Blossom Valley  95123             10
# 9999    M   2021-10-08   29.0      Santa Teresa  95138             10
#
# [3000 rows x 18 columns]

# %%
import math

def add_week_of_month(df):
    df['week_in_month'] = pd.to_numeric(df['Closing Date'].dt.day/7)
    df['week_in_month'] = df['week_in_month'].apply(lambda x: math.ceil(x))
    return df

# %%
add_week_of_month(train)
# Out:
#      Unit  DOM      LP      SP  BT  SqFt  BR  Bth  Gar  GarSp   YrBlt HOA Fee  \
# 0     NaN   17  769000  759000  CO  1257   2    2    Y    2.0  1999.0     341
# 1     NaN   51  649000  636000  CO   922   2    2  NaN    0.0  1988.0     460
# 2     NaN    7  750000  785000  TH  1655   3    2    Y    2.0  1982.0     445
# 3     NaN   15  674888  723000  DE  1408   3    3  NaN    0.0  1953.0     NaN
# 4     NaN    7  549000  600000  TH  1234   2    1    Y    2.0  1981.0     284
# ...   ...  ...     ...     ...  ..   ...  ..  ...  ...    ...     ...     ...
# 6995  416    4  849000  822000  CO  1622   2    2    Y    2.0  1998.0     726
# 6996  NaN    1  715000  766000  CO  1168   2    2    Y    2.0  1996.0     260
# 6997  NaN    9  887999  894000  DE  1568   4    2    Y    2.0  1998.0      50
# 6998    8    6  889500  905000  CO  1464   2    2  NaN    0.0  2013.0     210
# 6999    8   12  889500  905000  CO  1464   2    2    Y    2.0  2013.0     210
#
#      Freq Closing Date   Age              Area    Zip  month_of_date  \
# 0     NaN   2019-01-02  19.0      Santa Teresa  95138              1
# 1     NaN   2019-01-02  30.0          Campbell  95128              1
# 2     NaN   2019-01-02  36.0      Santa Teresa  95139              1
# 3     NaN   2019-01-02  65.0         Alum Rock  95127              1
# 4     NaN   2019-01-02  37.0         Evergreen  95121              1
# ...   ...          ...   ...               ...    ...            ...
# 6995    M   2020-12-22  22.0  Central San Jose  95112             12
# 6996    M   2020-12-22  24.0    South San Jose  95136             12
# 6997    M   2020-12-22  22.0    South San Jose  95111             12
# 6998    M   2020-12-22   8.0         Berryessa  95132             12
# 6999    M   2020-12-22   7.0         Berryessa  95132             12
#
#       week_in_month
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 6995              4
# 6996              4
# 6997              4
# 6998              4
# 6999              4
#
# [7000 rows x 19 columns]

# %%
add_week_of_month(test)
# Out:
#      Unit  DOM      LP      SP  BT  SqFt  BR  Bth  Gar  GarSp   YrBlt HOA Fee  \
# 7000  NaN    6  799999  935000  DE  1398   4    2    Y    2.0  1971.0     NaN
# 7001    2   14  514000  505000  CO   903   2    1    Y    1.0  1970.0     379
# 7002  NaN   25  549000  550000  CO  1094   2    2  NaN    0.0  1991.0     463
# 7003  NaN   10  949000  985000  DE  1065   3    2    Y    2.0  1971.0     NaN
# 7004  NaN   14  900000  915000  DE  1439   3    2  NaN    0.0  1920.0     NaN
# ...   ...  ...     ...     ...  ..   ...  ..  ...  ...    ...     ...     ...
# 9995  NaN   56  460000  450000  CO  1240   2    2  NaN    0.0  1968.0     822
# 9996  NaN    7  549000  615000  CO  1008   2    1    Y    2.0  1987.0     320
# 9997  NaN    0  650000  685000  CO  1452   3    2    Y    2.0  1986.0     380
# 9998  NaN    5  667053  675000  CO  1233   2    2    Y    1.0  1985.0     535
# 9999    E   24  699000  715000  TH  1093   2    2    Y    1.0  1992.0     349
#
#      Freq Closing Date    Age              Area    Zip  month_of_date  \
# 7000  NaN   2020-12-22   49.0         Evergreen  95148             12
# 7001    M   2020-12-22   50.0          Cambrian  95118             12
# 7002    M   2020-12-23   29.0    South San Jose  95122             12
# 7003  NaN   2020-12-23   49.0    Blossom Valley  95123             12
# 7004  NaN   2020-12-23  100.0  Central San Jose  95112             12
# ...   ...          ...    ...               ...    ...            ...
# 9995    M   2021-10-08   53.0         Evergreen  95135             10
# 9996    M   2021-10-08   34.0    South San Jose  95111             10
# 9997  NaN   2021-10-08   35.0    Blossom Valley  95136             10
# 9998    M   2021-10-08   36.0    Blossom Valley  95123             10
# 9999    M   2021-10-08   29.0      Santa Teresa  95138             10
#
#       week_in_month
# 7000              4
# 7001              4
# 7002              4
# 7003              4
# 7004              4
# ...             ...
# 9995              2
# 9996              2
# 9997              2
# 9998              2
# 9999              2
#
# [3000 rows x 19 columns]
